# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
drinks=pd.read_csv("drinks.csv")

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.set_index("country")
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# ...

# %%
drinks.set_index(["continent","country"])
# Out:
#                            beer_servings  spirit_servings  wine_servings  \
# continent     country
# Asia          Afghanistan              0                0              0
# Europe        Albania                 89              132             54
# Africa        Algeria                 25                0             14
# Europe        Andorra                245              138            312
# Africa        Angola                 217               57             45
# ...                                  ...              ...            ...
# South America Venezuela              333              100              3
# Asia          Vietnam                111                2              1
#               Yemen                    6                0              0
# Africa        Zambia                  32               19              4
#               Zimbabwe                64               18              4
#
#                            total_litres_of_pure_alcohol
# ...

# %%
drink_sort=drinks.set_index(["continent","country"]).sort_index()

# %%
drink_sort
# Out:
#                             beer_servings  spirit_servings  wine_servings  \
# continent     country
# Africa        Algeria                  25                0             14
#               Angola                  217               57             45
#               Benin                    34                4             13
#               Botswana                173               35             35
#               Burkina Faso             25                7              7
# ...                                   ...              ...            ...
# South America Paraguay                213              117             74
#               Peru                    163              160             21
#               Suriname                128              178              7
#               Uruguay                 115               35            220
#               Venezuela               333              100              3
#
#                             total_litres_of_pure_alcohol
# ...

# %%
drink_sort.head(10)
# Out:
#                                     beer_servings  spirit_servings  \
# continent country
# Africa    Algeria                              25                0
#           Angola                              217               57
#           Benin                                34                4
#           Botswana                            173               35
#           Burkina Faso                         25                7
#           Burundi                              88                0
#           Cabo Verde                          144               56
#           Cameroon                            147                1
#           Central African Republic             17                2
#           Chad                                 15                1
#
#                                     wine_servings  \
# continent country
# Africa    Algeria                              14
#           Angola                               45
# ...

# %%
drinks_africa=drinks["continent"]=="Africa"

# %%
drinks_africa
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 188    False
# 189    False
# 190    False
# 191     True
# 192     True
# Name: continent, Length: 193, dtype: bool

# %%
drinks_africa_c=drinks[drinks["continent"]=="Africa"]

# %%
drinks_africa_c
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
drinks_africa_c.size
# Out:
# 318

# %%
drinks_africa_c.shape
# Out:
# (53, 6)

# %%
drinks_africa_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 2 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       53 non-null     object
#  1   beer_servings                 53 non-null     int64
#  2   spirit_servings               53 non-null     int64
#  3   wine_servings                 53 non-null     int64
#  4   total_litres_of_pure_alcohol  53 non-null     float64
#  5   continent                     53 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.9+ KB

# %%
drinks["country"]=="Nigeria"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: country, Length: 193, dtype: bool

# %%
drinks_nig=drinks_africa_c[drinks["country"]=="Nigeria"]
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_844/280424092.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   drinks_nig=drinks_africa_c[drinks["country"]=="Nigeria"]

# %%
drinks_nig
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 124  Nigeria             42                5              2
#
#      total_litres_of_pure_alcohol continent
# 124                           9.1    Africa

# %%
drinks_nig.set_index("country")
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Nigeria             42                5              2
#
#          total_litres_of_pure_alcohol continent
# country
# Nigeria                           9.1    Africa

# %%
drinks_nig.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
drinks_nig.set_index("country").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# #how,why,what

# %%
import pandas as pd

# %%
df=pd.read_csv("drinks.csv")

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
df.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df["beer_servings"].max()
# Out:
# 376

# %%
df["beer_servings"]==376
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: beer_servings, Length: 193, dtype: bool

# %%
df[df["beer_servings"]==376]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa

# %%
df["beer_servings"].min()
# Out:
# 0

# %%
df["beer_servings"]==0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: beer_servings, Length: 193, dtype: bool

# %%
df[df["beer_servings"]==0]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 40       Cook Islands              0              254             74
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# ...

# %%
df[df["beer_servings"]==0].shape
# Out:
# (15, 6)

# %% [markdown]
# # method 2

# %%
df.beer_servings.sort_values(ascending=False)
# Out:
# 117    376
# 45     361
# 62     347
# 65     346
# 98     343
#       ...
# 107      0
# 158      0
# 111      0
# 128      0
# 0        0
# Name: beer_servings, Length: 193, dtype: int64

# %%
df["total_consumption"]=df.beer_servings+df.wine_servings+df.spirit_servings+df.total_litres_of_pure_alcohol

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_consumption
# 0                           0.0      Asia                0.0
# 1                           4.9    Europe              279.9
# 2                           0.7    Africa               39.7
# 3                          12.4    Europe              707.4
# 4                           5.9    Africa              324.9

# %%
df.iloc[:,1:5].sum()
# Out:
# beer_servings                   20489.0
# spirit_servings                 15632.0
# wine_servings                    9544.0
# total_litres_of_pure_alcohol      910.4
# dtype: float64

# %%
df.iloc[:,1:5].sum(axis=1)
# Out:
# 0        0.0
# 1      279.9
# 2       39.7
# 3      707.4
# 4      324.9
#        ...
# 188    443.7
# 189    116.0
# 190      6.1
# 191     57.5
# 192     90.7
# Length: 193, dtype: float64

# %%
df["mud_sum"]=df.iloc[:,1:5].sum(axis=1)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_consumption  mud_sum
# 0                           0.0      Asia                0.0      0.0
# 1                           4.9    Europe              279.9    279.9
# 2                           0.7    Africa               39.7     39.7
# 3                          12.4    Europe              707.4    707.4
# 4                           5.9    Africa              324.9    324.9

# %%
df.drop(["mud_sum"],axis=1,inplace=True)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_consumption
# 0                           0.0      Asia                0.0
# 1                           4.9    Europe              279.9
# 2                           0.7    Africa               39.7
# 3                          12.4    Europe              707.4
# 4                           5.9    Africa              324.9

# %%
df.total_consumption.max()
# Out:
# 707.4

# %%
df.total_consumption==707.4
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: total_consumption, Length: 193, dtype: bool

# %%
highest_cons=df[df.total_consumption==707.4]

# %%
highest_cons
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 3  Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent  total_consumption
# 3                          12.4    Europe              707.4

# %%
highest_cons.set_index("country").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='country'>
